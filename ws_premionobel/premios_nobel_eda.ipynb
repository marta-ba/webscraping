# %%
import pandas as pd

# Leer el archivo CSV
df = pd.read_csv('premios_nobel_literatura.csv')

# Mostrar las cinco primeras líneas
print(df.head(3))
# Out:
#     Año                 Nombre             País   Idioma
# 0  1901        Sully Prudhomme          Francia  Francés
# 1  1902        Theodor Mommsen   Imperio alemán   Alemán
# 2  1903  Bjørnstjerne Bjørnson  Noruega Noruega  Noruego

# %%
import matplotlib.pyplot as plt
df.País.value_counts().head(10).plot(kind='bar')
# Out:
# <Axes: xlabel='País'>

# %%
df.Idioma.value_counts().head(10).plot(kind='bar')
# Out:
# <Axes: xlabel='Idioma'>
